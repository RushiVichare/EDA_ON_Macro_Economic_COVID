# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import glob
from tqdm import tqdm

# %%
df_crude = pd.read_csv('F:\STOCK\CRUDEOIL.csv')

# %%
df_inr = pd.read_csv(r'F:\STOCK\USINR.csv')

# %%
df_gdp = pd.read_csv(r'F:\STOCK\GDP.csv')

# %%
df_dol = pd.read_csv(r'F:\STOCK\DOLI.csv')

# %%
df_ten = pd.read_csv(r'F:\STOCK\TENY.csv')

# %%
df_crude.head()
# Out:
#          DATE DCOILWTICO
# 0  2019-01-02      46.31
# 1  2019-01-03      46.92
# 2  2019-01-04      47.76
# 3  2019-01-07      48.27
# 4  2019-01-08      49.58

# %%
df_crude.shape
# Out:
# (783, 2)

# %%
df_crude.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        783 non-null    object
#  1   DCOILWTICO  783 non-null    object
# dtypes: object(2)
# memory usage: 12.4+ KB

# %%
df_crude.isnull().sum()/len(df_crude)
# Out:
# DATE          0.0
# DCOILWTICO    0.0
# dtype: float64

# %%
df_crude['DATE'] = pd.to_datetime(df_crude['DATE'])
df_crude["DCOILWTICO"] = pd.to_numeric(df_crude["DCOILWTICO"] ,errors='coerce')

# %%
df_crude.dtypes
# Out:
# DATE          datetime64[ns]
# DCOILWTICO           float64
# dtype: object

# %%
 df_crude.rename(columns = {'DCOILWTICO':'CRUDEOIL'}, inplace = True)

# %%
df_crude.head()
# Out:
#         DATE  CRUDEOIL
# 0 2019-01-02     46.31
# 1 2019-01-03     46.92
# 2 2019-01-04     47.76
# 3 2019-01-07     48.27
# 4 2019-01-08     49.58

# %%
df_inr.head()
# Out:
#          DATE DEXINUS
# 0  2019-01-02   70.02
# 1  2019-01-03   70.12
# 2  2019-01-04   69.63
# 3  2019-01-07   69.78
# 4  2019-01-08   70.11

# %%
df_inr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     783 non-null    object
#  1   DEXINUS  783 non-null    object
# dtypes: object(2)
# memory usage: 12.4+ KB

# %%
df_inr.isnull().sum()/len(df_inr)
# Out:
# DATE       0.0
# DEXINUS    0.0
# dtype: float64

# %%
df_inr.shape
# Out:
# (783, 2)

# %%
df_inr['DATE'] = pd.to_datetime(df_inr['DATE'])
df_inr["DEXINUS"] = pd.to_numeric(df_inr["DEXINUS"] ,errors='coerce')

# %%
df_inr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     783 non-null    datetime64[ns]
#  1   DEXINUS  748 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.4 KB

# %%
df_inr.describe()
# Out:
#           DEXINUS
# count  748.000000
# mean    72.820348
# std      2.096044
# min     68.400000
# 25%     71.150000
# 50%     73.245000
# 75%     74.510000
# max     76.950000

# %%
df_inr.rename(columns = {'DEXINUS':'USINR'}, inplace = True)

# %%
df_inr.head()
# Out:
#         DATE  USINR
# 0 2019-01-02  70.02
# 1 2019-01-03  70.12
# 2 2019-01-04  69.63
# 3 2019-01-07  69.78
# 4 2019-01-08  70.11

# %%
df_gdp.head()
# Out:
#          DATE      GDPC1
# 0  2019-01-01  18835.411
# 1  2019-04-01  18962.175
# 2  2019-07-01  19130.932
# 3  2019-10-01  19215.691
# 4  2020-01-01  18989.877

# %%
df_gdp.shape
# Out:
# (13, 2)

# %%
df_gdp['DATE'] = pd.to_datetime(df_gdp['DATE'])
df_gdp["GDPC1"] = pd.to_numeric(df_gdp["GDPC1"] ,errors='coerce')

# %%
df_gdp.head()
# Out:
#         DATE      GDPC1
# 0 2019-01-01  18835.411
# 1 2019-04-01  18962.175
# 2 2019-07-01  19130.932
# 3 2019-10-01  19215.691
# 4 2020-01-01  18989.877

# %%
df_dol.head()
# Out:
#          DATE  RTWEXBGS
# 0  2019-01-01  106.0298
# 1  2019-02-01  106.0958
# 2  2019-03-01  106.5692
# 3  2019-04-01  106.6433
# 4  2019-05-01  107.4452

# %%
df_dol.isnull().sum()
# Out:
# DATE        0
# RTWEXBGS    0
# dtype: int64

# %%
df_dol.rename(columns = {'RTWEXBGS':'DOLLIND'}, inplace = True)

# %%
df_dol.shape
# Out:
# (37, 2)

# %%
df_dol.head()
# Out:
#          DATE   DOLLIND
# 0  2019-01-01  106.0298
# 1  2019-02-01  106.0958
# 2  2019-03-01  106.5692
# 3  2019-04-01  106.6433
# 4  2019-05-01  107.4452

# %%
df_dol['DATE'] = pd.to_datetime(df_dol['DATE'])

# %%
df_dol.dtypes
# Out:
# DATE       datetime64[ns]
# DOLLIND           float64
# dtype: object

# %%
df_ten.head()
# Out:
#          DATE T10Y2Y
# 0  2019-01-02   0.16
# 1  2019-01-03   0.17
# 2  2019-01-04   0.17
# 3  2019-01-07   0.17
# 4  2019-01-08   0.15

# %%
df_ten.shape
# Out:
# (523, 2)

# %%
df_ten.dtypes
# Out:
# DATE      object
# T10Y2Y    object
# dtype: object

# %%
df_ten['DATE'] = pd.to_datetime(df_ten['DATE'])
df_ten["T10Y2Y"] = pd.to_numeric(df_ten["T10Y2Y"] ,errors='coerce')

# %%
df_dol.rename(columns = {'T10Y2Y':'TENYIELD'}, inplace = True)

# %%
df1 = pd.merge(df_crude, df_gdp, how="outer", on="DATE")

# %%
df2 = pd.merge(df_dol,df_ten,how ='outer',on='DATE')

# %%
df = pd.merge(pd.merge(df1,df2,on='DATE'),df_inr,on='DATE')

# %%
df.shape
# Out:
# (532, 6)

# %%
df.isnull().sum()
# Out:
# DATE          0
# CRUDEOIL     21
# GDPC1       521
# DOLLIND     506
# T10Y2Y       31
# USINR        24
# dtype: int64

# %%
df.fillna(method='ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# DATE         0
# CRUDEOIL     0
# GDPC1       63
# DOLLIND     22
# T10Y2Y       0
# USINR        0
# dtype: int64

# %%
df.GDPC1.fillna(method='bfill',inplace =True)

# %%
df.DOLLIND.fillna(method='bfill',inplace = True)

# %%
df.isnull().sum()
# Out:
# DATE        0
# CRUDEOIL    0
# GDPC1       0
# DOLLIND     0
# T10Y2Y      0
# USINR       0
# dtype: int64

# %%
df.head()
# Out:
#         DATE  CRUDEOIL      GDPC1   DOLLIND  T10Y2Y  USINR
# 0 2019-01-02     46.31  18962.175  106.0958    0.16  70.02
# 1 2019-01-03     46.92  18962.175  106.0958    0.17  70.12
# 2 2019-01-04     47.76  18962.175  106.0958    0.17  69.63
# 3 2019-01-07     48.27  18962.175  106.0958    0.17  69.78
# 4 2019-01-08     49.58  18962.175  106.0958    0.15  70.11

# %%
df.shape
# Out:
# (532, 6)

# %%
df.dtypes
# Out:
# DATE        datetime64[ns]
# CRUDEOIL           float64
# GDPC1              float64
# DOLLIND            float64
# T10Y2Y             float64
# USINR              float64
# dtype: object

# %%
year = df['DATE'].dt.strftime('%Y')

# %%
month = df['DATE'].dt.strftime('%B')

# %% [markdown]
# # EDA

# %%
sns.lineplot(data=df, x= year,y = df['CRUDEOIL'])
plt.title("India's CRUDE OIL PRICE OVER A 2019-2022")
plt.show()

# %%
x=year
y=df['CRUDEOIL']
plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('CRUDEOIL')
plt.show()

# %% [markdown]
# # AS YEAR DISTRUBUTION OVER 2019-2021 WE CAN SEE THE CRUDE OIL PRICE WAS DECREASED....AROUND 2020 IT WAS COVID MAJOR SECTION OF COVID

# %%
sns.lineplot(data=df, x= year,y = df['GDPC1'])
plt.title("India's GDP PRICE OVER A 2019-2022")
plt.show()

# %%
x=year
y=df['GDPC1']
plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('GDP')
plt.show()

# %%
sns.lineplot(data=df, x= year,y = df['DOLLIND'])
plt.title("India's DOLLAR INDEX PRICE OVER A 2019-2022")
plt.show()

# %%
x=year
y=df['DOLLIND']
plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('DOLLAR INDEX')
plt.show()

# %%
sns.lineplot(data=df, x= year,y = df['T10Y2Y'])
plt.title("India's 10 YEAR YIELD OVER A 2019-2022")
plt.show()

# %%
x=year
y=df['T10Y2Y']
plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('10YYIELD')
plt.show()

# %%
sns.lineplot(data=df, x= year,y = df['USINR'])
plt.title("USINR OVER A 2019-2022")
plt.show()

# %%
x=year
y=df['USINR']
plt.plot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('USINR')
plt.show()

# %%
plt.figure(figsize=(15,4))
x=month
y=df['CRUDEOIL']
sns.barplot(x,y,data = df)
plt.xticks(rotation=90)
plt.xlabel('YEAR EACH MONTH')
plt.ylabel('CRUDE OIL')
plt.show()
# Out:
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
x=month
y=df['DOLLIND']
sns.barplot(x,y,data = df)
plt.xticks(rotation=90)
plt.xlabel('YEAR EACH MONTH')
plt.ylabel('DOLLAR INDEX')
plt.show()
# Out:
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x=month
y=df['T10Y2Y']
sns.barplot(x,y,data= df)
plt.xticks(rotation=90)
plt.xlabel('YEAR EACH MONTH')
plt.ylabel('10YYIELD')
plt.show()
# Out:
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x=month
y=df['GDPC1']
sns.barplot(x,y,data = df)
plt.xticks(rotation=90)
plt.xlabel('YEAR EACH MONTH')
plt.ylabel('GDP')
plt.show()
# Out:
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
x = year
y1 = df['CRUDEOIL']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('YEAR')
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['CRUDEOIL','USINR'])
plt.show()



x = month
y1 = df['CRUDEOIL']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('MONTHS')
plt.xticks(rotation=90)
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['CRUDEOIL','USINR'])
plt.show()

# %%
x = year
y1 = df['DOLLIND']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('YEAR')
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['DOLLIND','USINR'])
plt.show()



x = month
y1 = df['DOLLIND']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('MONTHS')
plt.xticks(rotation=90)
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['DOLLIND','USINR'])
plt.show()

# %%
x = year
y1 = df['GDPC1']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('YEAR')
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['GDPC1','USINR'])
plt.show()



x = month
y1 = df['GDPC1']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('MONTHS')
plt.xticks(rotation=90)
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['GDPC1','USINR'])
plt.show()

# %%
x = year
y1 = df['T10Y2Y']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('YEAR')
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['T10Y2Y','USINR'])
plt.show()



x = month
y1 = df['T10Y2Y']
y2 = df['USINR']
 
plt.bar(x, y1, color='r')
plt.xlabel('MONTHS')
plt.xticks(rotation=90)
plt.bar(x, y2, bottom=y1, color='b')
plt.legend(['T10Y2Y','USINR'])
plt.show()

# %%
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpdates
import numpy as np
import plotly
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import init_notebook_mode

# %%
init_notebook_mode(connected = True)
 


 

fig = go.Figure(data=[go.Pie(labels=year,
                      values= df['USINR'])])
 
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
init_notebook_mode(connected = True)
 


 

fig = go.Figure(data=[go.Pie(labels=year,
                      values= df['CRUDEOIL'])])

     
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
init_notebook_mode(connected = True)
 


 

fig = go.Figure(data=[go.Pie(labels=year,
                      values= df['GDPC1'])])
 
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
init_notebook_mode(connected = True)
 


 

fig = go.Figure(data=[go.Pie(labels=year,
                      values= df['DOLLIND'])])
 
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df.columns
# Out:
# Index(['DATE', 'CRUDEOIL', 'GDPC1', 'DOLLIND', 'T10Y2Y', 'USINR'], dtype='object')

# %%
init_notebook_mode(connected = True)
 


 

fig = go.Figure(data=[go.Pie(labels=year,
                      values= df['T10Y2Y'])])
 
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
x=year
y=df['CRUDEOIL']
sns.boxplot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('CRUDEOIL')
plt.show()


x=year
y=df['GDPC1']
sns.boxplot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('GDP')
plt.show()


x=year
y=df['DOLLIND']
sns.boxplot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('DOLLAR INDEX')
plt.show()


x=year
y=df['T10Y2Y']
sns.boxplot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('10YYIELD')
plt.show()

x=year
y=df['USINR']
sns.boxplot(x,y)
plt.xticks(rotation=90)
plt.xlabel('YEAR')
plt.ylabel('USINR')
plt.show()
# Out:
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# C:\Users\JAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# ...
